# %%
import pandas as pd
import os
from dash import dash_table
from dash import html
from IPython.display import display

# %%
csv = "./cmdb_ci_computer.csv"
df = pd.read_csv(csv, encoding='ISO-8859-1')
display(df.head())
display(df.columns)
# Out:
#             name asset_tag                                              asset  \
# 0  com5cg1076ffb  21H01650  com5cg1076ffb - Hewlett-Packard EliteBook 845 ...
# 1  terwl21h01651  21H01651        terwl21h01651 - Hewlett-Packard 324B7UC#ABF
# 2  terwl21h01652  21H01652  21H01652 - Hewlett-Packard HP EliteBook 845 G7...
# 3  terwl21h01653  21H01653        terwl21h01653 - Hewlett-Packard 324B7UC#ABF
# 4  com5cg1076ffl  21H01654  com5cg1076ffl - Hewlett-Packard EliteBook 845 ...
#
#       assigned_to                        department        location  \
# 0   Antonio Ramos                   Manufacturing 1  TER NON-SEATED
# 1             NaN                               NaN         MAYENNE
# 2             NaN                               NaN         MAYENNE
# 3   Fabien Leloup  Primary & Small Molecule Quality  TER NON-SEATED
# 4  Olivier Hoarau                Mayenne Department  TER NON-SEATED
#
#   u_build_business_owner u_build_deployment_type u_build_primary_user  \
# ...

# %%
dt_soft = df[['name','asset_tag','asset','u_build_machine_use','assigned_to','hardware_substatus']]
display(dt_soft.head())
# Out:
#             name asset_tag                                              asset  \
# 0  com5cg1076ffb  21H01650  com5cg1076ffb - Hewlett-Packard EliteBook 845 ...
# 1  terwl21h01651  21H01651        terwl21h01651 - Hewlett-Packard 324B7UC#ABF
# 2  terwl21h01652  21H01652  21H01652 - Hewlett-Packard HP EliteBook 845 G7...
# 3  terwl21h01653  21H01653        terwl21h01653 - Hewlett-Packard 324B7UC#ABF
# 4  com5cg1076ffl  21H01654  com5cg1076ffl - Hewlett-Packard EliteBook 845 ...
#
#   u_build_machine_use     assigned_to hardware_substatus
# 0           Autopilot   Antonio Ramos             In Use
# 1                 STD             NaN          Available
# 2                 STD             NaN           Reserved
# 3                 STD   Fabien Leloup          Available
# 4           Autopilot  Olivier Hoarau          Available
